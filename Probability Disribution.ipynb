# %%
# Probability Distribution of Data
# Probability Density Function => Continuous Random Variables ex:Rainfall,Height,temparature5''
# Probability mass Function => Discrete random Variables ex:Age
# Cumulative Distribution/Density Function (PDF + PMF)

# %%
# Bernoulli Application -PMF => Discrete
# Applications
# Medical Trials
# Spam Detection

# %%
# poission for Fixed Interval => Discrete
# performing bernoulli multiple times is Binomial

# %%
# Guassian Distribution =>PDF Continous data
# Bell shaped curve
# Application Guassian or Normal
# Blood pressure
# Exam score

# %%
# Mean 0 SD 1 => Standard normal distribution
# Z-score => Outliers Standardization

# %%
# POWER LAW Distribution 80/20 law
# Applications:
# Wealth Distribution
# Internet

# %%
# Pareto Distribution (80/20) rule

# %% [markdown]
# **Bernoulli Distribution**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import bernoulli

# Define probability of success
p = 0.6

# Generate 1000 Bernoulli samples
data = bernoulli.rvs(p, size=1000)

# Plot the distribution
plt.bar([0, 1], [sum(data == 0), sum(data == 1)], color=['#DE3163', '#2D336B'], tick_label=["Failure (0)", "Success (1)"])
plt.xlabel("Outcome")
plt.ylabel("Frequency")
plt.title("Bernoulli Distribution (p=0.6)")
plt.show()

# %% [markdown]
# **Binomial Distribution**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# Define parameters
n = 10  # Total trials
p = 0.3  # Probability of success

# Generate Binomial distribution data
x = np.arange(0, n+1)
pmf = binom.pmf(x, n, p)

# Plot the Binomial Distribution
plt.bar(x, pmf, color='#008170', alpha=0.7)
plt.xlabel("Number of Successes (Clicks)")
plt.ylabel("Probability")
plt.title(f"Binomial Distribution (n={n}, p={p})")
plt.show()

# %% [markdown]
# **Poisson Distribution**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Define Lambda (average number of events per interval)
λ = 3

# Generate Poisson distribution datazzzzzzzzzz
x = np.arange(0, 10)  # Number of events (calls per minute)
pmf = poisson.pmf(x, λ)

# Plot the Poisson Distribution
plt.bar(x, pmf, color='#301E67', alpha=0.7)
plt.xlabel("Number of Calls per Minute")
plt.ylabel("Probability")
plt.title(f"Poisson Distribution (λ={λ})")
plt.show()

# %% [markdown]
# **Normal Distribution**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Define parameters
mu = 70    # Mean
sigma = 10 # Standard deviation

# Generate Normal distribution data
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 100)  # Range of scores
pdf = norm.pdf(x, mu, sigma)  # Compute PDF

# Plot the Normal Distribution
plt.plot(x, pdf, color='red', label=f"N({mu}, {sigma}²)")
plt.xlabel("Exam Scores")
plt.ylabel("Probability Density")
plt.title(f"Normal Distribution (μ={mu}, σ={sigma})")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# **Standard Normal Distribution**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Generate standard normal distribution data
z = np.linspace(-4, 4, 1000)  # Z-values from -4 to 4
pdf = norm.pdf(z, 0, 1)  # Standard Normal Distribution (μ=0, σ=1)

# Plot the Standard Normal Distribution
plt.plot(z, pdf, color='blue', label="Standard Normal Distribution (μ=0, σ=1)")
plt.xlabel("Z-Score")
plt.ylabel("Probability Density")
plt.title("Standard Normal Distribution (Z-Distribution)")
plt.axvline(x=0, color='red', linestyle='--', label="Mean (Z=0)")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# **Central Limit Theroem**
#     Convert data into Normal Distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set random seed for reproducibility
np.random.seed(42)

# Generate a skewed income dataset (exponential distribution)
income_data = np.random.exponential(scale=50, size=1000)

# Plot the original skewed distribution
plt.figure(figsize=(8, 4))
sns.histplot(income_data, bins=50, kde=True, color="r")
plt.title("Original Income Distribution (Skewed)")
plt.xlabel("Income ($1000)")
plt.ylabel("Frequency")
plt.show()

# Perform sampling and calculate means
sample_means = []
n_samples = 1000  # Number of samples
sample_size = 30  # Sample size

for _ in range(n_samples):
    sample = np.random.choice(income_data, sample_size, replace=True)
    sample_means.append(np.mean(sample))

# Plot the distribution of sample means
plt.figure(figsize=(8, 4))
sns.histplot(sample_means, bins=50, kde=True, color="b")
plt.title("Sampling Distribution of the Mean")
plt.xlabel("Sample Mean Income ($1000)")
plt.ylabel("Frequency")
plt.show()
